# %% [markdown]
# by **Ariel Rodrigo Colque Garcia**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Tue Dec 12 06:16:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install albumentations

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="oBkRYmxIVRFQKVIvhZVa")
project = rf.workspace("segmentacion-iwaek").project("medicinal_plants")
dataset = project.version(15).download("yolov8")
# Out:
# /content/datasets
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 930.9 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# !pip install kaggle

# %% [markdown]
# # Download the Kaggle dataset

# %%
from google.colab import files
files.upload() # sube el archivo kaggle.json desde la máquina local
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-7c9bc666-a7fe-4a12-a2b3-7bf4cd62be80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c9bc666-a7fe-4a12-a2b3-7bf4cd62be80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d rodrigocolque/medicinal-plants-15
# Out:
# ...
# 100% 12.7G/12.7G [02:55<00:00, 126MB/s]
# 100% 12.7G/12.7G [02:55<00:00, 77.8MB/s]

# %%
import zipfile
# Abre el archivo zip en modo lectura
with zipfile.ZipFile("/content/medicinal-plants-15.zip", "r") as zip_ref:
  # Extrae el contenido del archivo zip en la carpeta '/content'
  zip_ref.extractall("/content/medicinal-plants-15")

# %%
import os
# reemplaza 'ruta_de_tu_carpeta' con la ruta de tu carpeta
num_archivos = len(os.listdir('/content/datasets/medicinal_plants-15/train/images'))
print('Número de archivos en la carpeta:', num_archivos)
# Out:
# Número de archivos en la carpeta: 21304

# %%
import os

# reemplaza 'ruta_de_tu_carpeta' con la ruta de tu carpeta
num_archivos = len(os.listdir('/content/datasets/medicinal_plants-15/train/images'))

print('Número de Imagenes en la carpeta:', num_archivos)
# Out:
# Número de Imagenes en la carpeta: 21304

# %% [markdown]
# # TRAIN

# %%
# !ls /content/medicinal-plants-15
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !rm -rf /content/drive/MyDrive/USFX/TrainPlantsNANO

# %%
# !yolo task=segment mode=train model=yolov8l-seg.pt data=/content/datasets/medicinal_plants-15/data.yaml epochs=30 imgsz=640 project=/content/drive/MyDrive/USFX/TRAIN_LONGV2
# Out:
# ...
# 100% 88.1M/88.1M [00:00<00:00, 343MB/s]
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment resume mode=train model=/content/drive/MyDrive/USFX/TRAIN_LONGV2/train/weights/last.pt data=/content/datasets/medicinal_plants-15/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment resume mode=train model=/content/drive/MyDrive/USFX/TRAIN_LONGV2/train2/weights/last.pt data=/content/datasets/medicinal_plants-15/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment resume mode=train model=/content/drive/MyDrive/USFX/TRAIN_LONGV2/train4/weights/last.pt data=/content/datasets/medicinal_plants-15/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment resume mode=train model=/content/drive/MyDrive/USFX/TRAIN_LONGV2/train5/weights/last.pt data=/content/datasets/medicinal_plants-15/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # VALIDATION

# %%
# !yolo task=segment mode=val model=/content/drive/MyDrive/USFX/TRAIN_LONGV2/train6/weights/best.pt data=/content/datasets/medicinal_plants-15/data.yaml
# Out:
# 2023-12-12 10:09:49.974805: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-12 10:09:49.974868: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-12 10:09:49.974921: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-12 10:09:51.822251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45917285 parameters, 0 gradients, 220.2 GFLOPs
# ...

# %% [markdown]
# # INFERENCIA

# %%
# !yolo task=segment mode=predict model=/content/drive/MyDrive/USFX/TRAIN_LONGV2/train6/weights/best.pt conf=0.25 source=/content/datasets/medicinal-plants-15/test/images save=true
# Out:
# 2023-12-12 10:12:06.215568: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-12 10:12:06.215630: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-12 10:12:06.215670: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-12 10:12:07.250699: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45917285 parameters, 0 gradients, 220.2 GFLOPs
#
# Traceback (most recent call last):
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/segment/predict/*.jpg')[:20]:
      display(Image(filename=image_path, height=600))
      print("\n")

# %%
# %cd /content
# Out:
# /content

# %%
model = YOLO('/content/drive/MyDrive/USFX/TRAIN_LONGV2/train6/weights/best.pt')
image_path = '/content/drive/MyDrive/USFX/test_images/ultimo.mp4'
results1 = model.predict(source=image_path, conf=0.5, save=True)
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45917285 parameters, 0 gradients, 220.2 GFLOPs
#
# video 1/1 (1/1773) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/ultimo.mp4: 640x384 84.4ms
# video 1/1 (2/1773) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/ultimo.mp4: 640x384 48.1ms
# video 1/1 (3/1773) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/ultimo.mp4: 640x384 48.5ms
# video 1/1 (4/1773) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/ultimo.mp4: 640x384 48.0ms
# video 1/1 (5/1773) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/ultimo.mp4: 640x384 45.5ms
# video 1/1 (6/1773) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/ultimo.mp4: 640x384 41.7ms
# ...

# %%
# %cd /content
# Out:
# /content

# %%
model = YOLO('/content/drive/MyDrive/USFX/TRAIN_LONGV2/train6/weights/best.pt')
image_path = '/content/drive/MyDrive/USFX/test_images/VID_20231126_091315.mp4'
results1 = model.predict(source=image_path, conf=0.5, save=True)
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45917285 parameters, 0 gradients, 220.2 GFLOPs
#
# video 1/1 (1/858) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231126_091315.mp4: 640x384 1 menta_silvestre, 69.8ms
# video 1/1 (2/858) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231126_091315.mp4: 640x384 1 menta_silvestre, 48.1ms
# video 1/1 (3/858) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231126_091315.mp4: 640x384 1 menta_silvestre, 48.2ms
# video 1/1 (4/858) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231126_091315.mp4: 640x384 1 menta_silvestre, 48.3ms
# ...

# %%
model = YOLO('/content/drive/MyDrive/USFX/TRAIN_LONGV2/train6/weights/best.pt')
image_path = '/content/drive/MyDrive/USFX/test_images/VID_20231125_103435.mp4'
results1 = model.predict(source=image_path, conf=0.50, save=True)
# VID_20231207_144841.mp4
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45917285 parameters, 0 gradients, 220.2 GFLOPs
#
# video 1/1 (1/1925) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231125_103435.mp4: 640x384 1 menta_silvestre, 97.3ms
# video 1/1 (2/1925) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231125_103435.mp4: 640x384 1 malva, 51.1ms
# video 1/1 (3/1925) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231125_103435.mp4: 640x384 1 malva, 95.1ms
# video 1/1 (4/1925) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231125_103435.mp4: 640x384 48.0ms
# video 1/1 (5/1925) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231125_103435.mp4: 640x384 1 malva, 48.0ms
# ...

# %%
model = YOLO('/content/drive/MyDrive/USFX/TRAIN_LONGV2/train6/weights/best.pt')
image_path = '/content/drive/MyDrive/USFX/test_images/VID_20231207_144841.mp4'
results1 = model.predict(source=image_path, conf=0.50, save=True)
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45917285 parameters, 0 gradients, 220.2 GFLOPs
#
# video 1/1 (1/2278) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231207_144841.mp4: 640x384 1 menta_silvestre, 45.9ms
# video 1/1 (2/2278) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231207_144841.mp4: 640x384 38.9ms
# video 1/1 (3/2278) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231207_144841.mp4: 640x384 55.1ms
# video 1/1 (4/2278) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231207_144841.mp4: 640x384 44.2ms
# video 1/1 (5/2278) /content/drive/.shortcut-targets-by-id/1PMK2jYkIv9Tr8q2l0vA4eL263IMJ4VAF/test_images/VID_20231207_144841.mp4: 640x384 38.9ms
# ...

# %% [markdown]
# # EXPORT THE MODEL

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 56.6/78.2 GB disk)

# %% [markdown]
# Export a YOLOv8 model to any supported format below with the `format` argument, i.e. `format=onnx`. See [YOLOv8 Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://onnx.ai/) or [OpenVINO](https://docs.openvino.ai/latest/index.html) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://developer.nvidia.com/tensorrt) for up to 5x GPU speedup.
#
#
# | Format                                                             | `format` Argument | Model                     | Metadata | Arguments                                           |
# |--------------------------------------------------------------------|-------------------|---------------------------|----------|-----------------------------------------------------|
# | [PyTorch](https://pytorch.org/)                                    | -                 | `yolov8n.pt`              | ✅        | -                                                   |
# | [TorchScript](https://pytorch.org/docs/stable/jit.html)            | `torchscript`     | `yolov8n.torchscript`     | ✅        | `imgsz`, `optimize`                                 |
# | [ONNX](https://onnx.ai/)                                           | `onnx`            | `yolov8n.onnx`            | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `opset`     |
# | [OpenVINO](https://docs.openvino.ai/latest/index.html)             | `openvino`        | `yolov8n_openvino_model/` | ✅        | `imgsz`, `half`                                     |
# | [TensorRT](https://developer.nvidia.com/tensorrt)                  | `engine`          | `yolov8n.engine`          | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `workspace` |
# | [CoreML](https://github.com/apple/coremltools)                     | `coreml`          | `yolov8n.mlpackage`       | ✅        | `imgsz`, `half`, `int8`, `nms`                      |
# | [TF SavedModel](https://www.tensorflow.org/guide/saved_model)      | `saved_model`     | `yolov8n_saved_model/`    | ✅        | `imgsz`, `keras`                                    |
# | [TF GraphDef](https://www.tensorflow.org/api_docs/python/tf/Graph) | `pb`              | `yolov8n.pb`              | ❌        | `imgsz`                                             |
# | [TF Lite](https://www.tensorflow.org/lite)                         | `tflite`          | `yolov8n.tflite`          | ✅        | `imgsz`, `half`, `int8`                             |
# | [TF Edge TPU](https://coral.ai/docs/edgetpu/models-intro/)         | `edgetpu`         | `yolov8n_edgetpu.tflite`  | ✅        | `imgsz`                                             |
# | [TF.js](https://www.tensorflow.org/js)                             | `tfjs`            | `yolov8n_web_model/`      | ✅        | `imgsz`                                             |
# | [PaddlePaddle](https://github.com/PaddlePaddle)                    | `paddle`          | `yolov8n_paddle_model/`   | ✅        | `imgsz`                                             |
# | [ncnn](https://github.com/Tencent/ncnn)                            | `ncnn`            | `yolov8n_ncnn_model/`     | ✅        | `imgsz`, `half`                                     |

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# Out:
# /content

# %%
# !yolo export model='/content/drive/MyDrive/USFX/TrainPlantsNANO/train8/weights/best.pt' format=tflite imgsz=320
# Out:
# 2023-12-11 14:25:38.034239: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 14:25:38.034309: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 14:25:38.034349: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 14:25:39.118943: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU
# YOLOv8n-seg summary (fused): 195 layers, 3259429 parameters, 0 gradients, 12.0 GFLOPs
#
# ...
